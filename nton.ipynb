# %%
pip install pandas scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
df = pd.read_csv("synthetic_laptop_data.csv")
print(df.head())
print("\n")
X = df[['RAM_GB', 'GPU_Score', 'Processor_GHz']]
y = df['Type']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test
print("Accuracy:", accuracy_score(y_test, y_pred))
features = ['RAM_GB', 'GPU_Score', 'Processor_GHz']
coefficients = model.coef_[0]

plt.bar(features, coefficients, color='skyblue')
plt.title('Feature Coefficients (Weights)')
plt.xlabel('Features')
plt.ylabel('Coefficient Value')
plt.show()
custom_laptop = [[4, 1000, 10]]
prediction = model.predict(custom_laptop)
print("Recommended For:", "Gaming" if prediction[0] == 1 else "General Use")
# Out:
#    RAM_GB  GPU_Score  Processor_GHz  Type
# 0      32      17453           4.91     1
# 1      64       1194           4.93     0
# 2      16       6224           2.44     0
# 3      64      19679           1.64     0
# 4      64       1504           3.97     0
#
#
# Accuracy: 0.832
# Recommended For: Gaming
# C:\Users\prath\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
